# %%
#http://nbviewer.ipython.org/github/jakevdp/sklearn_pydata2015/blob/master/notebooks/04.1-Dimensionality-PCA.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# use seaborn plotting style defaults
import seaborn as sns; sns.set()

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
y = digits.target

# %%
pca = PCA(2) # project from 64 to 2 dimensions of data
#PCA(0.95) totally cut dimensions for keeping 95% of variance
Xproj = pca.fit_transform(X)
print(X.shape, Xproj.shape)
# Out:
# (1797, 64) (1797, 2)

# %%
# %matplotlib inline
plt.scatter(Xproj[:, 0], Xproj[:, 1], c=y, edgecolor='none', alpha=0.5, \
            cmap=plt.cm.get_cmap('nipy_spectral', 10))
plt.colorbar()
